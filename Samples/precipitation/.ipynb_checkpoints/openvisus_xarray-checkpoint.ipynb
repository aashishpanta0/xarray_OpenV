# %%
# %%time
from backend_v2 import *
import rioxarray as rio
import xarray as xr
from OpenVisus import *
import matplotlib.pyplot as plt
# %matplotlib inline

filename='dummy.idx'
# Out:
# /Users/aashishpanta/opt/anaconda3/lib/python3.8/site-packages/xarray/backends/cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(
# Starting OpenVisus /Users/aashishpanta/opt/anaconda3/lib/python3.8/site-packages/OpenVisus/__init__.py 3.8.12 (default, Oct 12 2021, 06:23:56)
# [Clang 10.0.0 ] sys.version_info(major=3, minor=8, micro=12, releaselevel='final', serial=0) ...
# CPU times: user 1.23 s, sys: 1.22 s, total: 2.46 s
# Wall time: 1.47 s

# %%
# %%time
data = rio.open_rasterio('pr_2020.nc')
data.attrs['units'] = 'mm'
d1=data.values
shutil.rmtree(os.path.dirname(filename), ignore_errors=True)
db=CreateIdx(url=filename, dim=3, data=d1,field=[Field('percipitation amount', 'float64')])
data.dims
# Out:
# CPU times: user 52.3 s, sys: 4.48 s, total: 56.8 s
# Wall time: 57.3 s
# ('day', 'y', 'x')

# %%
# %%time
ds = xr.open_dataset("dummy.idx",engine=OpenVisusBackendEntrypoint,coords=data.coords,attrs=data.attrs,dims=data.dims)
d1=ds.DATA[:366,:585,:1386]
d1.attrs=data.attrs
d1.shape
# Out:
# Adding field  DATA shape  [366, 585, 1386] dtype  uint16 labels  ['day', 'y', 'x'] timesteps  [0] Max Resolution  30
# CPU times: user 8.41 ms, sys: 5.31 ms, total: 13.7 ms
# Wall time: 12 ms
# (366, 585, 1386)

# %%
a=d1.values
plt.plot(ds['day'],a[:,100,100])
# Out:
# _raw_indexing_method key (slice(0, 366, 1), slice(0, 585, 1), slice(0, 1386, 1))
# Using Max Resolution:  30
# (366, 585, 1386)

# %%
miss_val=d1.attrs['missing_value']
d_masked = d1.where(d1 != miss_val)
# d1.coords

# %%
d_masked
# Out:
# <xarray.DataArray 'DATA' (day: 366, y: 585, x: 1386)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
# ...

# %%
# %%time
d_masked.mean(dim='day').plot()
# Out:
# CPU times: user 1.13 s, sys: 1.66 s, total: 2.79 s
# Wall time: 3.22 s
