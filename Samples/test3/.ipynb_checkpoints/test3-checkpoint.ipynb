# %%
import xarray as xr
import numpy as np
import pandas as pd
from OpenVisus import *
from backend_v2 import *
# Out:
# Starting OpenVisus /Users/aashishpanta/opt/anaconda3/lib/python3.8/site-packages/OpenVisus/__init__.py 3.8.12 (default, Oct 12 2021, 06:23:56)
# [Clang 10.0.0 ] sys.version_info(major=3, minor=8, micro=12, releaselevel='final', serial=0) ...
# /Users/aashishpanta/opt/anaconda3/lib/python3.8/site-packages/xarray/backends/cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
data = xr.open_dataset('adaptor.mars.internal-1649414946.8898907-5323-20-d2ffcb96-4834-405b-af4d-1fea50c5d810.nc')
# len(data['tp'].dims)
a=data['tp']
a
# Out:
# <xarray.DataArray 'tp' (time: 1, latitude: 721, longitude: 1440)>
# [1038240 values with dtype=float32]
# Coordinates:
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2003-06-01
# Attributes:
#     units:      m
#     long_name:  Total precipitation

# %%
filename='dummy.idx'
shutil.rmtree(os.path.dirname(filename), ignore_errors=True)
db=CreateIdx(url=filename, dim=len(data.dims), data=a[0].values,fields=[Field('tp','float32','row_major')])
db

# %%
# %%time
ds = xr.open_dataset("dummy.idx",engine=OpenVisusBackendEntrypoint,coords=a[0].coords,attrs=a[0].attrs,dims=a[0].dims)
d1=ds.isel(latitude=slice(0,721),longitude=slice(0,1440))
ds.DATA
# Out:
# Adding field  DATA shape  [721, 1440] dtype  float32 labels  ['latitude', 'longitude'] timesteps  [0] Max Resolution  21
# CPU times: user 13.8 ms, sys: 3.02 ms, total: 16.9 ms
# Wall time: 15.6 ms
# <xarray.DataArray 'DATA' (latitude: 721, longitude: 1440)>
# [1038240 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] ...
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
