# %%
import xarray as xr
import numpy as np
import pandas as pd
from OpenVisus import *
from backend_v2 import *

# %% [markdown]
# ## Loading netcdf file usign xarray

# %%
data = xr.open_dataset('precip.comb.v2018to2016-v6monitorafter.total.nc')
# data=data.to_array()
# data['precip']
data['precip'].attrs
data['precip']
# Out:
# <xarray.DataArray 'precip' (time: 1548, lat: 180, lon: 360)>
# [100310400 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 89.5 88.5 87.5 86.5 85.5 ... -86.5 -87.5 -88.5 -89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * time     (time) datetime64[ns] 1891-01-01 1891-02-01 ... 2019-12-01
# Attributes:
#     long_name:     GPCC Monthly total of precipitation
#     statistic:     Total
#     valid_range:   [   0. 8000.]
#     parent_stat:   Observations
#     var_desc:      Precipitation
#     units:         mm
#     level:         Surface
#     actual_range:  [   0.   3349.61]
#     dataset:       GPCC Precipitation 1.0degree V2018 Full Reanalysis

# %% [markdown]
# ## Loading dataset into idx using openvisus

# %%
filename='dummy.idx'

# %%
shutil.rmtree(os.path.dirname(filename), ignore_errors=True)
db=CreateIdx(url=filename, dim=len(data.dims), data=data['precip'].values,fields=[Field('precip','float32','row_major')])
db

# %%
# %%time
ds = xr.open_dataset("dummy.idx",engine=OpenVisusBackendEntrypoint,coords=data['precip'].coords,attrs=data['precip'].attrs,dims=data['precip'].dims)

d1=ds.isel(time=slice(0,1),lat=slice(0,180),lon=slice(0,360))
d1
# Out:
# Adding field  precip shape  [1548, 180, 360] dtype  float32 labels  ['time', 'lat', 'lon'] timesteps  [0] Max Resolution  28
# CPU times: user 9.08 ms, sys: 2.88 ms, total: 12 ms
# Wall time: 9.54 ms
# _raw_indexing_method key (slice(0, 1, 1), slice(0, 180, 1), slice(0, 360, 1))
# Using Max Resolution:  28
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 180, lon: 360)
# Coordinates:
#   * lat      (lat) float32 89.5 88.5 87.5 86.5 85.5 ... -86.5 -87.5 -88.5 -89.5
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * time     (time) datetime64[ns] 1891-01-01
# Data variables:
#     precip   (time, lat, lon) float32 ...
# Attributes:
#     long_name:     GPCC Monthly total of precipitation
#     statistic:     Total
#     valid_range:   [   0. 8000.]
#     parent_stat:   Observations
#     var_desc:      Precipitation
#     units:         mm
#     level:         Surface
#     actual_range:  [   0.   3349.61]
#     dataset:       GPCC Precipitation 1.0degree V2018 Full Reanalysis
