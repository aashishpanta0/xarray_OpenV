# %%
import numpy as np
import pandas as pd
import xarray as xr

# %%
data=np.random.random(size=100).reshape(5,20)

# %%
xar=xr.DataArray(data, dims=['x','y'], coords={'x':np.arange(10,15), 'y':np.arange(20)}, attrs={'x':' random 5', 'y':'random 20'})
xar
# Out:
# <xarray.DataArray (x: 5, y: 20)>
# array([[0.39273712, 0.26558019, 0.60985229, 0.56336176, 0.68996969,
#         0.13080425, 0.95410919, 0.50610781, 0.13713313, 0.19482339,
#         0.95762091, 0.94956713, 0.36578961, 0.26270374, 0.3030905 ,
#         0.43206439, 0.38280522, 0.6201539 , 0.09880139, 0.61330747],
#        [0.74316992, 0.44138168, 0.46526627, 0.81044933, 0.42920258,
#         0.36953162, 0.1432542 , 0.52386579, 0.66972354, 0.30454949,
#         0.80957948, 0.86491197, 0.92338837, 0.65778747, 0.90685305,
#         0.94114175, 0.78070022, 0.38752351, 0.78745204, 0.55993342],
#        [0.48400423, 0.36444714, 0.66348333, 0.4871053 , 0.57591106,
#         0.49660794, 0.48290096, 0.6494044 , 0.56558678, 0.64778647,
#         0.20540604, 0.46215234, 0.88323645, 0.09939511, 0.3230708 ,
#         0.05888972, 0.52401151, 0.82598065, 0.63569787, 0.05024444],
#        [0.87663062, 0.31442416, 0.62950224, 0.25737396, 0.99636103,
# ...
